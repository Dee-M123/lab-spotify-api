# %% [markdown]
# # Installing Spotipy

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.12/dist-packages (2.25.2)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.12/dist-packages (from spotipy) (7.2.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.12/dist-packages (from spotipy) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->spotipy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->spotipy) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->spotipy) (2026.1.4)

# %% [markdown]
# ## Loading credentials from the config file

# %% [markdown]
# #### Make sure that you have stored your spotify client_id and client_secret in a separate config.py file
# #### Once that's done, we import it

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials

# %%
import os
from google.colab import userdata


client_id = userdata.get("Spotify_id")
client_secret = userdata.get("Spotify_Key")

# %%
import pprint

# %%
# Authenticate
auth_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=auth_manager)

print(sp)
# Out:
# <spotipy.client.Spotify object at 0x7bb88b645910>

# %%
results = sp.search(q="With You", type="track", limit=1)

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=With%20You&type=track',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#                                               'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#                                               'id': '7bXgB6jMjp9ATFy66eO08Z',
#                                               'name': 'Chris Brown',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6p5pW2WwgVECsOhrXPAyhI'},
#                                  'href': 'https://api.spotify.com/v1/albums/6p5pW2WwgVECsOhrXPAyhI',
#                                  'id': '6p5pW2WwgVECsOhrXPAyhI',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27339509cc5eadf803928f2f167',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0239509cc5eadf803928f2f167',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485139509cc5eadf803928f2f167',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Exclusive (Expanded Edition)',
#                                  'release_date': '2007-11-06',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 18,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6p5pW2WwgVECsOhrXPAyhI'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#                                     'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#                                     'id': '7bXgB6jMjp9ATFy66eO08Z',
#                                     'name': 'Chris Brown',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#                        'disc_number': 1,
#                        'duration_ms': 252120,
#                        'explicit': False,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5Lgcn7u07bHuqbOtXkN62u'},
#                        'href': 'https://api.spotify.com/v1/tracks/5Lgcn7u07bHuqbOtXkN62u',
#                        'id': '5Lgcn7u07bHuqbOtXkN62u',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'With You',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:5Lgcn7u07bHuqbOtXkN62u'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=With%20You&type=track',
#             'offset': 0,
#             'previous': None,
#             'total': 1000}}

# %% [markdown]
# # Understanding the json

# %%
track = results['tracks']['items'][0]

print("Track Name:", track['name'])
print("Artist:", track['artists'][0]['name'])
print("Album:", track['album']['name'])
# Out:
# Track Name: With You
# Artist: Chris Brown
# Album: Exclusive (Expanded Edition)

# %% [markdown]
# ## Other Info

# %% [markdown]
# ## Getting the track_id

# %%
# Search for a track
results = sp.search(q="NdiKuze", type="track", limit=1)

# Extract track_id
track = results['tracks']['items'][0]
track_id = track['id']

print("Track Name:", track['name'])
print("Artist:", track['artists'][0]['name'])
print("Track ID:", track_id)
# Out:
# Track Name: NdiKuze
# Artist: Focalistic
# Track ID: 1kxXK0kzTQyxl0DaMthWMt

# %% [markdown]
# ## Embedded track player

# %%
from IPython.display import IFrame

# %%
embed_url = f"https://open.spotify.com/embed/track/{track_id}"

IFrame(embed_url, width=300, height=380)
# Out:
#         <iframe
#             width="300"
#             height="380"
#             src="https://open.spotify.com/embed/track/1kxXK0kzTQyxl0DaMthWMt"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %% [markdown]
# ## Building a Data frame of audio features

# %% [markdown]
# ## Searching a playlist

# %%
results = sp.search(q="Today's Top Hits", type="playlist", limit=5)

if results and results.get('playlists'):

    playlists = results['playlists'].get('items', [])

    valid_playlist = None

    for p in playlists:
        if p is not None:   # 🔥 skip None entries
            valid_playlist = p
            break

    if valid_playlist:
        playlist_id = valid_playlist['id']
        print("Playlist Found!")
        print("Name:", valid_playlist['name'])
        print("Playlist ID:", playlist_id)
    else:
        print("No valid playlists found.")

else:
    print("Search failed.")
# Out:
# Playlist Found!
# Name: R&B 2026 🔥 New R&B Hits / Top RnB Songs
# Playlist ID: 3We3LenpVndqS3rUCP0MeY

# %% [markdown]
# ## Extracting a song from playlist

# %%
playlist_id = "3We3LenpVndqS3rUCP0MeY"

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=client_id,
    client_secret=client_secret,
    redirect_uri="http://127.0.0.1:8888/callback",
    scope="playlist-read-private playlist-read-collaborative"
))

# %%
playlist_id = "3We3LenpVndqS3rUCP0MeY"

playlist_tracks = sp.playlist_tracks(playlist_id, limit=50)

for item in playlist_tracks['items']:
    track = item.get('track')
    if track:
        print(track['name'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-619371601.py in <cell line: 0>()
#       1 playlist_id = "3We3LenpVndqS3rUCP0MeY"
#       2
# ----> 3 playlist_tracks = sp.playlist_tracks(playlist_id, limit=50)
#       4
#       5 for item in playlist_tracks['items']:
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     706             DeprecationWarning,
#     707         )
# --> 708         return self.playlist_items(playlist_id, fields, limit, offset,
#     709                                    market, additional_types)
#     710
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     730         """
#     731         plid = self._get_id("playlist", playlist_id)
# --> 732         return self._get(
#     733             f"playlists/{plid}/tracks",
#     734             limit=limit,
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# --> 321         return self._internal_call("GET", url, payload, kwargs)
#     322
#     323     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     245         if not url.startswith("http"):
#     246             url = self.prefix + url
# --> 247         headers = self._auth_headers()
#     248
#     249         if "content_type" in args["params"]:
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _auth_headers(self)
#     236             return {}
#     237         try:
# --> 238             token = self.auth_manager.get_access_token(as_dict=False)
#     239         except TypeError:
#     240             token = self.auth_manager.get_access_token()
#
# /usr/local/lib/python3.12/dist-packages/spotipy/oauth2.py in get_access_token(self, code, as_dict, check_cache)
#     511         payload = {
#     512             "redirect_uri": self.redirect_uri,
# --> 513             "code": code or self.get_auth_response(),
#     514             "grant_type": "authorization_code",
#     515         }
#
# /usr/local/lib/python3.12/dist-packages/spotipy/oauth2.py in get_auth_response(self, open_browser)
#     467             # Only start a local http server if a port is specified
#     468             if redirect_port:
# --> 469                 return self._get_auth_response_local_server(redirect_port)
#     470             else:
#     471                 logger.warning(f'Using `{redirect_host}` as redirect URI without a port. '
#
# /usr/local/lib/python3.12/dist-packages/spotipy/oauth2.py in _get_auth_response_local_server(self, redirect_port)
#     423
#     424     def _get_auth_response_local_server(self, redirect_port):
# --> 425         server = start_local_http_server(redirect_port)
#     426         self._open_auth_url()
#     427         server.handle_request()
#
# /usr/local/lib/python3.12/dist-packages/spotipy/oauth2.py in start_local_http_server(port, handler)
#    1283
#    1284 def start_local_http_server(port, handler=RequestHandler):
# -> 1285     server = HTTPServer(("127.0.0.1", port), handler)
#    1286     server.allow_reuse_address = True
#    1287     server.auth_code = None
#
# /usr/lib/python3.12/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     455         if bind_and_activate:
#     456             try:
# --> 457                 self.server_bind()
#     458                 self.server_activate()
#     459             except:
#
# /usr/lib/python3.12/http/server.py in server_bind(self)
#     134     def server_bind(self):
#     135         """Override server_bind to store the server name."""
# --> 136         socketserver.TCPServer.server_bind(self)
#     137         host, port = self.server_address[:2]
#     138         self.server_name = socket.getfqdn(host)
#
# /usr/lib/python3.12/socketserver.py in server_bind(self)
#     476         ):
#     477             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 478         self.socket.bind(self.server_address)
#     479         self.server_address = self.socket.getsockname()
#     480
#
# OSError: [Errno 98] Address already in use

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next".
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %% [markdown]
# ### Chopping a big playlist into chunks

# %% [markdown]
# ### Example with rock

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %% [markdown]
# Example: Coldplay

# %% [markdown]
# ## Getting the songs of a given album
